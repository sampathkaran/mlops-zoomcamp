# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parquet.py:491, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     437 @doc(storage_options=_shared_docs["storage_options"])
#     438 def read_parquet(
#     439     path,
#    (...)
#     444     **kwargs,
#     445 ) -> DataFrame:
#     446     """
#     447     Load a parquet object from the file path, returning a DataFrame.
#     448
#    (...)
#     489     DataFrame
#     490     """
# --> 491     impl = get_engine(engine)
#     493     return impl.read(
#     494         path,
#     495         columns=columns,
#    (...)
#     498         **kwargs,
#     499     )
#
# ...

# %%
# !pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.3 MB 8.3 kB/s eta 0:00:01
# ...

# %%
pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet')
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-02-01 00:04:45   2024-02-01 00:19:58              1.0
# 1               2  2024-02-01 00:56:31   2024-02-01 01:10:53              1.0
# 2               2  2024-02-01 00:07:50   2024-02-01 00:43:12              2.0
# 3               1  2024-02-01 00:01:49   2024-02-01 00:10:47              1.0
# 4               1  2024-02-01 00:37:35   2024-02-01 00:51:15              1.0
# ...           ...                  ...                   ...              ...
# 3007521         2  2024-02-29 23:20:17   2024-02-29 23:28:25              NaN
# 3007522         2  2024-02-29 23:38:37   2024-02-29 23:49:37              NaN
# 3007523         2  2024-02-29 23:14:40   2024-02-29 23:19:29              NaN
# 3007524         1  2024-02-29 23:12:06   2024-02-29 23:21:53              NaN
# 3007525         2  2024-02-29 23:16:42   2024-02-29 23:37:45              NaN
#
# ...

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-02-01 00:04:45   2024-02-01 00:19:58              1.0
# 1               2  2024-02-01 00:56:31   2024-02-01 01:10:53              1.0
# 2               2  2024-02-01 00:07:50   2024-02-01 00:43:12              2.0
# 3               1  2024-02-01 00:01:49   2024-02-01 00:10:47              1.0
# 4               1  2024-02-01 00:37:35   2024-02-01 00:51:15              1.0
# ...           ...                  ...                   ...              ...
# 3007521         2  2024-02-29 23:20:17   2024-02-29 23:28:25              NaN
# 3007522         2  2024-02-29 23:38:37   2024-02-29 23:49:37              NaN
# 3007523         2  2024-02-29 23:14:40   2024-02-29 23:19:29              NaN
# 3007524         1  2024-02-29 23:12:06   2024-02-29 23:21:53              NaN
# 3007525         2  2024-02-29 23:16:42   2024-02-29 23:37:45              NaN
#
# ...

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-02-01 00:04:45   2024-02-01 00:19:58              1.0
# 1         2  2024-02-01 00:56:31   2024-02-01 01:10:53              1.0
# 2         2  2024-02-01 00:07:50   2024-02-01 00:43:12              2.0
# 3         1  2024-02-01 00:01:49   2024-02-01 00:10:47              1.0
# 4         1  2024-02-01 00:37:35   2024-02-01 00:51:15              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           4.39         1.0                  N            68           236
# 1           7.71         1.0                  N            48           243
# 2          28.69         2.0                  N           132           261
# 3           1.10         1.0                  N           161           163
# 4           2.60         1.0                  N           246            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'
